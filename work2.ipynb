# %%
import utils
import models
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os.path

import numpy as np
from matplotlib import pyplot as plt

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

def plot_heatmap(data, annotation):
    fig, ax = plt.subplots(figsize=(17,17)) 
    sns.heatmap(data, annot = annotation, vmin = -1, vmax = 1, fmt = '', ax = ax)
    ax.invert_yaxis()
    plt.show()

# %%
sample_data = utils.get_data('./sample1.txt')
char2idx_dict, idx2char_dict = utils.get_dicts(sample_data)

# %%
lstm = torch.load("lstm-2-100-0.1.pkl")
a = lstm.
print(a)
# Out:
# None

# %%
output, hidden =

# %%
uniform_data = (np.random.rand(30, 30) - 0.5) * 2
c = np.array([['a'] * 30] * 30)

# %%
plot_heatmap(uniform_data, c)
